# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("outputs/all.csv")
train = pd.read_csv("outputs/train.csv")
test = pd.read_csv("outputs/val.csv")
df
# Out:
#         hr  yday  mday  wday  wend  week  mnth  qrtr     t  gas  ...   l3  \
# 0        2    10    10     1     0     2     1     1   5.0  112  ...  112
# 1        3    10    10     1     0     2     1     1   5.0  112  ...  112
# 2        3    10    10     1     0     2     1     1   5.0  224  ...  112
# 3        4    10    10     1     0     2     1     1   5.0  112  ...  112
# 4        4    10    10     1     0     2     1     1   5.0  112  ...  112
# ...     ..   ...   ...   ...   ...   ...   ...   ...   ...  ...  ...  ...
# 145981  22   151    31     3     0    22     5     2  15.0  112  ...  112
# 145982  22   151    31     3     0    22     5     2  15.0  112  ...  112
# 145983  23   151    31     3     0    22     5     2  15.7  112  ...  112
# 145984  23   151    31     3     0    22     5     2  15.7  112  ...  112
# 145985   0   152     1     4     0    22     6     2  15.7  112  ...  112
#
#          l4   l5       rmean   rmed       rstd  rslope    rskew  rkurt  state
# 0       112  224  130.666667  112.0  45.723809   -16.0  2.44949    6.0      0
# 1       112  112  112.000000  112.0   0.000001     0.0  0.00000    0.0      0
# 2       112  112  130.666667  112.0  45.723809    16.0  2.44949    6.0      0
# 3       112  112  130.666667  112.0  45.723809     9.6  2.44949    6.0      0
# 4       112  112  130.666667  112.0  45.723809     3.2  2.44949    6.0      0
# ...     ...  ...         ...    ...        ...     ...      ...    ...    ...
# 145981  112  112  112.000000  112.0   0.002025     0.0  0.00000    0.0      0
# 145982  112  112  112.000000  112.0   0.002025     0.0  0.00000    0.0      0
# 145983  112  112  112.000000  112.0   0.002025     0.0  0.00000    0.0      0
# 145984  112  112  112.000000  112.0   0.002025     0.0  0.00000    0.0      0
# 145985  112  112  112.000000  112.0   0.002025     0.0  0.00000    0.0      0
#
# [145986 rows x 22 columns]

# %%
X_train = train.drop('state', axis=1)
y_train = train['state']
X_test = test.drop('state', axis=1)
y_test = test['state']

# %%
rf = RandomForestRegressor(n_estimators=150)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=150)

# %%
sort = rf.feature_importances_.argsort()
#plt.barh(X_train.feature_names[sort],rf.feature_importances_[sort])
plt.xlabel("Feature Importance")
# Out:
# Text(0.5, 0, 'Feature Importance')

# %%
# Importing libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from sklearn.svm import SVC
model = SVC(probability=True)
model.fit(X_train,y_train)
